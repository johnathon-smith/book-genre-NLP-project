# %% [markdown]
# # Acquire the Data

# %% [markdown]
# For this project, I will be web scraping thousands of books for their genres and cover blurbs. The overall goal of the project is to use NLP to predict a book's genre based on the brief summary usually available on the back of or inside the cover.

# %%
import numpy as np
import pandas as pd
from requests import get
from bs4 import BeautifulSoup
import re
import time

# %% [markdown]
# I will be getting the book information from Barnes and Noble's website. Based on the layout of the website, I believe I will need to first acquire the url's for each genre. From there, I will have to acquire the urls for each book inside that genre. Finally, I'll be able to access the book's individual url and scrape the book's cover blurb.

# %%
#To test whether or not I can scrape B&N, I will do a quick check here
url = 'https://www.barnesandnoble.com/b/books/fiction/horror/_/N-29Z8q8Z1d51'

# %%
response = get(url, headers = {'user-agent': 'Codeup DS Germain'})

# %%
response
# Out:
# 200

# %% [markdown]
# Test Successful! Now begin getting the urls for all sub-genres of horror.

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
#Find the list of sub-genres
sub_genres = soup.find('ul', id = 'sidebar-section-0')

# %%
#Now find all the anchor tags that contain the urls for each sub-genre
links = sub_genres.find_all('a')

# %%
#Now extract all of the href urls
links[0].attrs['href']
# Out:
# '/b/books/horror/ghost-stories/_/N-29Z8q8Z1d5e;jsessionid=2FF65370C9537EDACE18DAEDF6E7AFB7.prodny_store02-atgap13'

# %%
#Create empty list to store links
horror_links = []

# %%
#Loop through each item in the links list
for link in links:
    #Build the complete link
    complete_link = 'barnesandnoble.com' + link.attrs['href']
    
    #Everything after the semicolon in the url is not needed. Remove it
    complete_link = re.sub(r';.*', '', complete_link)
    
    #Append the new link to the list
    horror_links.append(complete_link)

# %%
horror_links
# Out:
# ['barnesandnoble.com/b/books/horror/ghost-stories/_/N-29Z8q8Z1d5e',
#  'barnesandnoble.com/b/books/horror/ghost-stories-other/_/N-29Z8q8Z1d52',
#  'barnesandnoble.com/b/books/horror/gothic-horror/_/N-29Z8q8Z1d5b',
#  'barnesandnoble.com/b/books/horror/gothic-horror-other/_/N-29Z8q8Z1d56',
#  'barnesandnoble.com/b/books/horror/horror-inner-demons/_/N-29Z8q8Z1d5g',
#  'barnesandnoble.com/b/books/horror/horror-lost-abandoned-and-alone/_/N-29Z8q8Z1d5h',
#  'barnesandnoble.com/b/books/horror/horror-other/_/N-29Z8q8Z1d53',
#  'barnesandnoble.com/b/books/horror/horror-sacred-and-profane/_/N-29Z8q8Z1d5i',
#  'barnesandnoble.com/b/books/horror/horror-anthologies/_/N-29Z8q8Z1d5d',
#  'barnesandnoble.com/b/books/horror/horror-anthologies-other/_/N-29Z8q8Z1d54',
#  'barnesandnoble.com/b/books/horror/horror-classics/_/N-29Z8q8Z1d5f',
#  'barnesandnoble.com/b/books/horror/horror-comics/_/N-29Z8q8Z1d5j',
#  'barnesandnoble.com/b/books/horror/horror-short-stories/_/N-29Z8q8Z1d5c',
#  'barnesandnoble.com/b/books/horror/psychological-horror/_/N-29Z8q8Z1d5a',
#  'barnesandnoble.com/b/books/horror/science-fiction-horror/_/N-29Z8q8Z2v8u',
#  'barnesandnoble.com/b/books/horror/supernatural-horror/_/N-29Z8q8Z1d59',
#  'barnesandnoble.com/b/books/horror/vampires/_/N-29Z8q8Z1d57',
#  'barnesandnoble.com/b/books/horror/werewolves-other-beasts/_/N-29Z8q8Z1d58',
#  'barnesandnoble.com/b/books/horror/zombies/_/N-29Z8q8Z1d55']

# %%
#Now build a function to do this for each over arching genre
#I'd like to get books in Horror, Romance, Mystery and Crime, and Sci-Fi and Fantasy 
def get_sub_genre_urls(genre_list):
    """
    This function takes in a list of dictionaries containing urls for the Horror, Romance, Sci-fi and Fantasy genres
    at barnesandnoble.com. Each dictionary also has the name of the genre for the link. 
    It then loops through each of them, web scrapes the urls for each
    sub genre, and finally returns a list of those urls.
    """
    #Create empty list to contain genre name and sub-genre url dicts
    sub_genres = []
    
    #Loop through each url in the genre_list
    for genre in genre_list:
        #Get the web content of the main genre
        response = get(genre['url'], headers = {'user-agent': 'Codeup DS Germain'})
        
        #Check status code, print message
        if response.status_code == 200:
            print(f'Response status code: {response.status_code}. The {genre["genre"]} genre is good to go.')
        else:
            print(f'Response status code: {response.status_code}. Something went wrong with the {genre["genre"]} genre!')
            
        #Parse the response
        soup = BeautifulSoup(response.content, 'html.parser')
        
        #Find the list of sub-genres
        sub_genre_list = soup.find('ul', id = 'sidebar-section-0')
        
        #Now find all the anchor tags that contain the urls for each sub-genre
        links = sub_genre_list.find_all('a')
        
        #Loop through each item in the links list
        for link in links:
            #Build the complete link
            complete_link = 'https://www.barnesandnoble.com' + link.attrs['href']

            #Everything after the semicolon in the url is not needed. Remove it
            complete_link = re.sub(r';.*', '', complete_link)

            #Build the dict to store the data
            temp_dict = {'genre': genre['genre'],
                         'sub-genre': complete_link.split('/')[-3],
                         'url': complete_link }
            
            #Append the new link to the list
            sub_genres.append(temp_dict)
            
    return sub_genres

# %%
#Test the above function
#Since there are only 4 overall genres, I will manually grab those urls.
genres = [{
            'genre': 'Horror',
            'url' : 'https://www.barnesandnoble.com/b/books/fiction/horror/_/N-29Z8q8Z1d51'
          },
          {
            'genre': 'Romance',
            'url': 'https://www.barnesandnoble.com/b/books/romance/_/N-29Z8q8Z17y3'
          },
          {
              'genre': 'Mystery and Crime',
              'url' : 'https://www.barnesandnoble.com/b/books/mystery-crime/_/N-29Z8q8Z16g4'
          },
          {
              'genre': 'Sci-Fi and Fantasy',
              'url': 'https://www.barnesandnoble.com/b/books/science-fiction-fantasy/_/N-29Z8q8Z180l'
          }]

# %%
#Now run the function and get the list of dictionaries containing the sub-genre urls
sub_genres = get_sub_genre_urls(genres)
# Out:
# Response status code: 200. The Horror genre is good to go.
# Response status code: 200. The Romance genre is good to go.
# Response status code: 200. The Mystery and Crime genre is good to go.
# Response status code: 200. The Sci-Fi and Fantasy genre is good to go.

# %%
sub_genres[0]
# Out:
# {'genre': 'Horror',
#  'sub-genre': 'ghost-stories',
#  'url': 'https://www.barnesandnoble.com/b/books/horror/ghost-stories/_/N-29Z8q8Z1d5e'}

# %%
len(sub_genres)
# Out:
# 43

# %% [markdown]
# Now, I have 43 different links. From here, I will create a process to gather all of the individual book links from each sub-genre. This will involve going through every page associated with the sub-genre.

# %%
response = get(sub_genres[0]['url'], headers = {'user-agent':'Codeup DS Germain'})

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
#First find out how many pages there are for the sub-genre
page_list = soup.find('ul', class_ = 'pagination search-pagination')

# %%
#Now gather the anchor tags in the list
a_tags = page_list.find_all('a')

# %%
#Since the last anchor tag is for the very next page,
#Select the second to last anchor tag. It will have the number associated with 
#the last page in the sub-genre
a_tags[-2]
# Out:
# <a href="https://www.barnesandnoble.com/b/books/horror/ghost-stories/_/N-29Z8q8Z1d5e?Nrpp=20&amp;page=29">
# <span class="sr-only">Page</span>
# 29</a>

# %%
last_page = int(a_tags[-2].text.split('\n')[2])
last_page
# Out:
# 29

# %% [markdown]
# Now, that we have the last page, we can loop through each page of the sub-genre without worry.

# %%
#Now grab the section that contains all of the books on the page
book_container = soup.find('div', class_ = 'product-shelf-grid')

# %%
#Now get all the links for each book
book_anchors = book_container.find_all('a', class_ = 'pImageLink')

# %%
book_anchors[0].attrs['href']
# Out:
# '/w/a-christmas-carol-charles-dickens/1116639901;jsessionid=5F788B4D0EBF133BDB386599E415C617.prodny_store02-atgap12?ean=9780486268651'

# %%
#Create list to hold all of the individual book urls
book_urls = []

# %%
#Now complete the href
#Loop through each item in the links list
for anchor in book_anchors:
    #Build the complete link
    complete_link = 'https://www.barnesandnoble.com' + anchor.attrs['href']
    
    #Everything after the semicolon in the url is not needed. Remove it
    complete_link = re.sub(r';.*', '', complete_link)
    
    #Create a temp_dict to store info
    temp_dict = {'genre': 'Horror',
                 'url': complete_link}
    
    #Append the new link to the list
    book_urls.append(temp_dict)

# %%
book_urls
# Out:
# [{'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/a-christmas-carol-charles-dickens/1116639901'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/we-have-always-lived-in-the-castle-shirley-jackson/1100733872'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/haunting-of-hill-house-shirley-jackson/1100285791'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/nothing-but-blackened-teeth-cassandra-khaw/1138427401'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/horrorstor-grady-hendrix/1117004682'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/the-whispering-dead-darcy-coates/1137754132'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/classic-ghost-stories-various/1134585800'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/a-christmas-carol-kareen-taylerson/1104780873'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/heart-shaped-box-joe-hill/1008007251'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/hell-house-richard-matheson/1100346664'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/odd-thomas-dean-koontz/1100266360'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/ghosts-edith-wharton/1000818636'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/ghost-story-peter-straub/1100402537'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/the-haunting-of-ashburn-house-darcy-coates/1124182367'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/the-invited-jennifer-mcmahon/1128957590'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/odd-apocalypse-dean-koontz/1107085329'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/turn-of-the-screw-henry-james/1002093959'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/odd-interlude-dean-koontz/1113137850'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/roald-dahls-book-of-ghost-stories-roald-dahl/1102949791'},
#  {'genre': 'Horror',
#   'url': 'https://www.barnesandnoble.com/w/the-haunting-of-blackwood-house-darcy-coates/1123330659'}]

# %%
#Create a function that gets the total number of pages available for a sub-genre
def get_last_page(soup):
    """
    This function takes in the content of an html page. It should be the first page for 
    any sub-genre. It will find and return the number corresponding to the last page 
    available for the sub-genre.
    """
    #Now, find out how many pages there are in the sub-genre
    page_list = soup.find('ul', class_ = 'pagination search-pagination')

    #Now gather the anchor tags in the list
    a_tags = page_list.find_all('a')
    
    #Since the last anchor tag is for the very next page,
    #Select the second to last anchor tag. It will have the number associated with 
    #the last page in the sub-genre
    last_page = int(a_tags[-2].text.split('\n')[2])
    
    return last_page

# %%
#Now build a function that gathers the book urls from all available pages in the sub-genre
def get_book_urls(sub_genres):
    """
    This function takes in a dictionary of sub-genre urls. It will loop through each of them
    and gather the individual book urls from all available pages in the sub-genre.
    It will return a list of dictionaries, with each dictionary containing the book's 
    overall genre and the individual book's url.
    """
    #First create an empty list to hold the book dictionaries
    book_urls = []
    
    #Now loop through each sub-genre
    for sub_genre in sub_genres:
        #Get the initial page for the sub-genre
        response = get(sub_genre['url'], headers = {'user-agent':'Codeup DS Germain'})
        
        #Check response
        if response.status_code == 200:
            print(f'Got first page of sub-genre: {sub_genre["genre"]}, {sub_genre["sub-genre"]}')
        else:
            print(f'Something went wrong at {sub_genre["genre"]}, {sub_genre["sub-genre"]}. Status code: {response.status_code}')
        
        #Parse it 
        soup = BeautifulSoup(response.content, 'html.parser')
        
        #Get the number corresponding to the last available page for the sub-genre
        last_page = get_last_page(soup)
        
        #Now increment through the pages
        for i in range(2, last_page + 1):
            
            #Scrape all book urls on the current page
            #Grab the section that contains all of the books on the page
            book_container = soup.find('div', class_ = 'product-shelf-grid')
            
            #Now get all the links for each book
            book_anchors = book_container.find_all('a', class_ = 'pImageLink')
    
            #Loop through each item in the links list
            for anchor in book_anchors:
                #Build the complete link
                complete_link = 'https://www.barnesandnoble.com' + anchor.attrs['href']

                #Everything after the semicolon in the url is not needed. Remove it
                complete_link = re.sub(r';.*', '', complete_link)

                #Create a temp_dict to store info
                temp_dict = {'genre': sub_genre['genre'],
                             'sub-genre': sub_genre['sub-genre'],
                             'url': complete_link}

                #Append the new link to the list
                book_urls.append(temp_dict)
                
            #Now create the url for the next page
            #I believe Nrpp stands for Num results per page, so we can change that if we want
            next_page = sub_genre['url'] + '?Nrpp=20&page=' + str(i)
            
            #Now get the content of the next page
            response = get(next_page, headers = {'user-agent': 'Codeup DS Germain'})
            
            #Check the response code again
            if response.status_code == 200:
                print(f'Acquired page {i} of {last_page} pages.')
            else:
                print(f'Something went wrong at page {i} of {last_page} pages! Status Code: {response.status_code}')
            
            #Now parse and update the soup variable for the next loop iteration
            soup = BeautifulSoup(response.content, 'html.parser')
            
    return book_urls

# %%
#Now run the function above and get the individual book urls
#Hopefully this is not going to take long
#Note: This took about half an hour
book_urls = get_book_urls(sub_genres)
# Out:
# Got first page of sub-genre: Horror, ghost-stories
# Acquired page 2 of 29 pages.
# Acquired page 3 of 29 pages.
# Acquired page 4 of 29 pages.
# Acquired page 5 of 29 pages.
# Acquired page 6 of 29 pages.
# Acquired page 7 of 29 pages.
# Acquired page 8 of 29 pages.
# Acquired page 9 of 29 pages.
# Acquired page 10 of 29 pages.
# Acquired page 11 of 29 pages.
# Acquired page 12 of 29 pages.
# Acquired page 13 of 29 pages.
# Acquired page 14 of 29 pages.
# Acquired page 15 of 29 pages.
# Acquired page 16 of 29 pages.
# Acquired page 17 of 29 pages.
# Acquired page 18 of 29 pages.
# Acquired page 19 of 29 pages.
# Acquired page 20 of 29 pages.
# Acquired page 21 of 29 pages.
# Acquired page 22 of 29 pages.
# Acquired page 23 of 29 pages.
# Acquired page 24 of 29 pages.
# Acquired page 25 of 29 pages.
# Acquired page 26 of 29 pages.
# Acquired page 27 of 29 pages.
# Acquired page 28 of 29 pages.
# Acquired page 29 of 29 pages.
# Got first page of sub-genre: Horror, ghost-stories-other
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Horror, gothic-horror
# Acquired page 2 of 24 pages.
# Acquired page 3 of 24 pages.
# Acquired page 4 of 24 pages.
# Acquired page 5 of 24 pages.
# Acquired page 6 of 24 pages.
# Acquired page 7 of 24 pages.
# Acquired page 8 of 24 pages.
# Acquired page 9 of 24 pages.
# Acquired page 10 of 24 pages.
# Acquired page 11 of 24 pages.
# Acquired page 12 of 24 pages.
# Acquired page 13 of 24 pages.
# Acquired page 14 of 24 pages.
# Acquired page 15 of 24 pages.
# Acquired page 16 of 24 pages.
# Acquired page 17 of 24 pages.
# Acquired page 18 of 24 pages.
# Acquired page 19 of 24 pages.
# Acquired page 20 of 24 pages.
# Acquired page 21 of 24 pages.
# Acquired page 22 of 24 pages.
# Acquired page 23 of 24 pages.
# Acquired page 24 of 24 pages.
# Got first page of sub-genre: Horror, gothic-horror-other
# Acquired page 2 of 2 pages.
# Got first page of sub-genre: Horror, horror-inner-demons
# Acquired page 2 of 10 pages.
# Acquired page 3 of 10 pages.
# Acquired page 4 of 10 pages.
# Acquired page 5 of 10 pages.
# Acquired page 6 of 10 pages.
# Acquired page 7 of 10 pages.
# Acquired page 8 of 10 pages.
# Acquired page 9 of 10 pages.
# Acquired page 10 of 10 pages.
# Got first page of sub-genre: Horror, horror-lost-abandoned-and-alone
# Acquired page 2 of 7 pages.
# Acquired page 3 of 7 pages.
# Acquired page 4 of 7 pages.
# Acquired page 5 of 7 pages.
# Acquired page 6 of 7 pages.
# Acquired page 7 of 7 pages.
# Got first page of sub-genre: Horror, horror-other
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Horror, horror-sacred-and-profane
# Acquired page 2 of 6 pages.
# Acquired page 3 of 6 pages.
# Acquired page 4 of 6 pages.
# Acquired page 5 of 6 pages.
# Acquired page 6 of 6 pages.
# Got first page of sub-genre: Horror, horror-anthologies
# Acquired page 2 of 20 pages.
# Acquired page 3 of 20 pages.
# Acquired page 4 of 20 pages.
# Acquired page 5 of 20 pages.
# Acquired page 6 of 20 pages.
# Acquired page 7 of 20 pages.
# Acquired page 8 of 20 pages.
# Acquired page 9 of 20 pages.
# Acquired page 10 of 20 pages.
# Acquired page 11 of 20 pages.
# Acquired page 12 of 20 pages.
# Acquired page 13 of 20 pages.
# Acquired page 14 of 20 pages.
# Acquired page 15 of 20 pages.
# Acquired page 16 of 20 pages.
# Acquired page 17 of 20 pages.
# Acquired page 18 of 20 pages.
# Acquired page 19 of 20 pages.
# Acquired page 20 of 20 pages.
# Got first page of sub-genre: Horror, horror-anthologies-other
# Acquired page 2 of 2 pages.
# Got first page of sub-genre: Horror, horror-classics
# Acquired page 2 of 7 pages.
# Acquired page 3 of 7 pages.
# Acquired page 4 of 7 pages.
# Acquired page 5 of 7 pages.
# Acquired page 6 of 7 pages.
# Acquired page 7 of 7 pages.
# Got first page of sub-genre: Horror, horror-comics
# Acquired page 2 of 43 pages.
# Acquired page 3 of 43 pages.
# Acquired page 4 of 43 pages.
# Acquired page 5 of 43 pages.
# Acquired page 6 of 43 pages.
# Acquired page 7 of 43 pages.
# Acquired page 8 of 43 pages.
# Acquired page 9 of 43 pages.
# Acquired page 10 of 43 pages.
# Acquired page 11 of 43 pages.
# Acquired page 12 of 43 pages.
# Acquired page 13 of 43 pages.
# Acquired page 14 of 43 pages.
# Acquired page 15 of 43 pages.
# Acquired page 16 of 43 pages.
# Acquired page 17 of 43 pages.
# Acquired page 18 of 43 pages.
# Acquired page 19 of 43 pages.
# Acquired page 20 of 43 pages.
# Acquired page 21 of 43 pages.
# Acquired page 22 of 43 pages.
# Acquired page 23 of 43 pages.
# Acquired page 24 of 43 pages.
# Acquired page 25 of 43 pages.
# Acquired page 26 of 43 pages.
# Acquired page 27 of 43 pages.
# Acquired page 28 of 43 pages.
# Acquired page 29 of 43 pages.
# Acquired page 30 of 43 pages.
# Acquired page 31 of 43 pages.
# Acquired page 32 of 43 pages.
# Acquired page 33 of 43 pages.
# Acquired page 34 of 43 pages.
# Acquired page 35 of 43 pages.
# Acquired page 36 of 43 pages.
# Acquired page 37 of 43 pages.
# Acquired page 38 of 43 pages.
# Acquired page 39 of 43 pages.
# Acquired page 40 of 43 pages.
# Acquired page 41 of 43 pages.
# Acquired page 42 of 43 pages.
# Acquired page 43 of 43 pages.
# Got first page of sub-genre: Horror, horror-short-stories
# Acquired page 2 of 28 pages.
# Acquired page 3 of 28 pages.
# Acquired page 4 of 28 pages.
# Acquired page 5 of 28 pages.
# Acquired page 6 of 28 pages.
# Acquired page 7 of 28 pages.
# Acquired page 8 of 28 pages.
# Acquired page 9 of 28 pages.
# Acquired page 10 of 28 pages.
# Acquired page 11 of 28 pages.
# Acquired page 12 of 28 pages.
# Acquired page 13 of 28 pages.
# Acquired page 14 of 28 pages.
# Acquired page 15 of 28 pages.
# Acquired page 16 of 28 pages.
# Acquired page 17 of 28 pages.
# Acquired page 18 of 28 pages.
# Acquired page 19 of 28 pages.
# Acquired page 20 of 28 pages.
# Acquired page 21 of 28 pages.
# Acquired page 22 of 28 pages.
# Acquired page 23 of 28 pages.
# Acquired page 24 of 28 pages.
# Acquired page 25 of 28 pages.
# Acquired page 26 of 28 pages.
# Acquired page 27 of 28 pages.
# Acquired page 28 of 28 pages.
# Got first page of sub-genre: Horror, psychological-horror
# Acquired page 2 of 27 pages.
# Acquired page 3 of 27 pages.
# Acquired page 4 of 27 pages.
# Acquired page 5 of 27 pages.
# Acquired page 6 of 27 pages.
# Acquired page 7 of 27 pages.
# Acquired page 8 of 27 pages.
# Acquired page 9 of 27 pages.
# Acquired page 10 of 27 pages.
# Acquired page 11 of 27 pages.
# Acquired page 12 of 27 pages.
# Acquired page 13 of 27 pages.
# Acquired page 14 of 27 pages.
# Acquired page 15 of 27 pages.
# Acquired page 16 of 27 pages.
# Acquired page 17 of 27 pages.
# Acquired page 18 of 27 pages.
# Acquired page 19 of 27 pages.
# Acquired page 20 of 27 pages.
# Acquired page 21 of 27 pages.
# Acquired page 22 of 27 pages.
# Acquired page 23 of 27 pages.
# Acquired page 24 of 27 pages.
# Acquired page 25 of 27 pages.
# Acquired page 26 of 27 pages.
# Acquired page 27 of 27 pages.
# Got first page of sub-genre: Horror, science-fiction-horror
# Acquired page 2 of 3 pages.
# Acquired page 3 of 3 pages.
# Got first page of sub-genre: Horror, supernatural-horror
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Horror, vampires
# Acquired page 2 of 27 pages.
# Acquired page 3 of 27 pages.
# Acquired page 4 of 27 pages.
# Acquired page 5 of 27 pages.
# Acquired page 6 of 27 pages.
# Acquired page 7 of 27 pages.
# Acquired page 8 of 27 pages.
# Acquired page 9 of 27 pages.
# Acquired page 10 of 27 pages.
# Acquired page 11 of 27 pages.
# Acquired page 12 of 27 pages.
# Acquired page 13 of 27 pages.
# Acquired page 14 of 27 pages.
# Acquired page 15 of 27 pages.
# Acquired page 16 of 27 pages.
# Acquired page 17 of 27 pages.
# Acquired page 18 of 27 pages.
# Acquired page 19 of 27 pages.
# Acquired page 20 of 27 pages.
# Acquired page 21 of 27 pages.
# Acquired page 22 of 27 pages.
# Acquired page 23 of 27 pages.
# Acquired page 24 of 27 pages.
# Acquired page 25 of 27 pages.
# Acquired page 26 of 27 pages.
# Acquired page 27 of 27 pages.
# Got first page of sub-genre: Horror, werewolves-other-beasts
# Acquired page 2 of 12 pages.
# Acquired page 3 of 12 pages.
# Acquired page 4 of 12 pages.
# Acquired page 5 of 12 pages.
# Acquired page 6 of 12 pages.
# Acquired page 7 of 12 pages.
# Acquired page 8 of 12 pages.
# Acquired page 9 of 12 pages.
# Acquired page 10 of 12 pages.
# Acquired page 11 of 12 pages.
# Acquired page 12 of 12 pages.
# Got first page of sub-genre: Horror, zombies
# Acquired page 2 of 25 pages.
# Acquired page 3 of 25 pages.
# Acquired page 4 of 25 pages.
# Acquired page 5 of 25 pages.
# Acquired page 6 of 25 pages.
# Acquired page 7 of 25 pages.
# Acquired page 8 of 25 pages.
# Acquired page 9 of 25 pages.
# Acquired page 10 of 25 pages.
# Acquired page 11 of 25 pages.
# Acquired page 12 of 25 pages.
# Acquired page 13 of 25 pages.
# Acquired page 14 of 25 pages.
# Acquired page 15 of 25 pages.
# Acquired page 16 of 25 pages.
# Acquired page 17 of 25 pages.
# Acquired page 18 of 25 pages.
# Acquired page 19 of 25 pages.
# Acquired page 20 of 25 pages.
# Acquired page 21 of 25 pages.
# Acquired page 22 of 25 pages.
# Acquired page 23 of 25 pages.
# Acquired page 24 of 25 pages.
# Acquired page 25 of 25 pages.
# Got first page of sub-genre: Romance, contemporary-romance
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Romance, historical-romance
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Romance, other-romance-categories
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Romance, paranormal-romance
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Romance, romantic-fiction-themes
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Mystery and Crime, cozy-mysteries-amateur-sleuths
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Mystery and Crime, crime-fiction
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Mystery and Crime, detective-fiction
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Mystery and Crime, multicultural-detectives-fiction
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Mystery and Crime, other-mystery-categories
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Mystery and Crime, police-stories
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Mystery and Crime, women-detectives-fiction
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Sci-Fi and Fantasy, alternate-realities-fiction
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Sci-Fi and Fantasy, fantasy-fiction
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Sci-Fi and Fantasy, high-tech-and-hard-science-fiction
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Sci-Fi and Fantasy, j-r-r-tolkien-the-lord-of-the-rings
# Acquired page 2 of 5 pages.
# Acquired page 3 of 5 pages.
# Acquired page 4 of 5 pages.
# Acquired page 5 of 5 pages.
# Got first page of sub-genre: Sci-Fi and Fantasy, other-fantasy-fiction-categories
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Sci-Fi and Fantasy, other-science-fiction-categories
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Sci-Fi and Fantasy, role-playing-game-fiction
# Acquired page 2 of 27 pages.
# Acquired page 3 of 27 pages.
# Acquired page 4 of 27 pages.
# Acquired page 5 of 27 pages.
# Acquired page 6 of 27 pages.
# Acquired page 7 of 27 pages.
# Acquired page 8 of 27 pages.
# Acquired page 9 of 27 pages.
# Acquired page 10 of 27 pages.
# Acquired page 11 of 27 pages.
# Acquired page 12 of 27 pages.
# Acquired page 13 of 27 pages.
# Acquired page 14 of 27 pages.
# Acquired page 15 of 27 pages.
# Acquired page 16 of 27 pages.
# Acquired page 17 of 27 pages.
# Acquired page 18 of 27 pages.
# Acquired page 19 of 27 pages.
# Acquired page 20 of 27 pages.
# Acquired page 21 of 27 pages.
# Acquired page 22 of 27 pages.
# Acquired page 23 of 27 pages.
# Acquired page 24 of 27 pages.
# Acquired page 25 of 27 pages.
# Acquired page 26 of 27 pages.
# Acquired page 27 of 27 pages.
# Got first page of sub-genre: Sci-Fi and Fantasy, science-fiction-fantasy-media-tie-in-fiction
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Sci-Fi and Fantasy, social-science-fiction
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Sci-Fi and Fantasy, space-exploration-fiction
# Acquired page 2 of 50 pages.
# Acquired page 3 of 50 pages.
# Acquired page 4 of 50 pages.
# Acquired page 5 of 50 pages.
# Acquired page 6 of 50 pages.
# Acquired page 7 of 50 pages.
# Acquired page 8 of 50 pages.
# Acquired page 9 of 50 pages.
# Acquired page 10 of 50 pages.
# Acquired page 11 of 50 pages.
# Acquired page 12 of 50 pages.
# Acquired page 13 of 50 pages.
# Acquired page 14 of 50 pages.
# Acquired page 15 of 50 pages.
# Acquired page 16 of 50 pages.
# Acquired page 17 of 50 pages.
# Acquired page 18 of 50 pages.
# Acquired page 19 of 50 pages.
# Acquired page 20 of 50 pages.
# Acquired page 21 of 50 pages.
# Acquired page 22 of 50 pages.
# Acquired page 23 of 50 pages.
# Acquired page 24 of 50 pages.
# Acquired page 25 of 50 pages.
# Acquired page 26 of 50 pages.
# Acquired page 27 of 50 pages.
# Acquired page 28 of 50 pages.
# Acquired page 29 of 50 pages.
# Acquired page 30 of 50 pages.
# Acquired page 31 of 50 pages.
# Acquired page 32 of 50 pages.
# Acquired page 33 of 50 pages.
# Acquired page 34 of 50 pages.
# Acquired page 35 of 50 pages.
# Acquired page 36 of 50 pages.
# Acquired page 37 of 50 pages.
# Acquired page 38 of 50 pages.
# Acquired page 39 of 50 pages.
# Acquired page 40 of 50 pages.
# Acquired page 41 of 50 pages.
# Acquired page 42 of 50 pages.
# Acquired page 43 of 50 pages.
# Acquired page 44 of 50 pages.
# Acquired page 45 of 50 pages.
# Acquired page 46 of 50 pages.
# Acquired page 47 of 50 pages.
# Acquired page 48 of 50 pages.
# Acquired page 49 of 50 pages.
# Acquired page 50 of 50 pages.
# Got first page of sub-genre: Sci-Fi and Fantasy, star-trek-fiction
# Acquired page 2 of 32 pages.
# Acquired page 3 of 32 pages.
# Acquired page 4 of 32 pages.
# Acquired page 5 of 32 pages.
# Acquired page 6 of 32 pages.
# Acquired page 7 of 32 pages.
# Acquired page 8 of 32 pages.
# Acquired page 9 of 32 pages.
# Acquired page 10 of 32 pages.
# Acquired page 11 of 32 pages.
# Acquired page 12 of 32 pages.
# Acquired page 13 of 32 pages.
# Acquired page 14 of 32 pages.
# Acquired page 15 of 32 pages.
# Acquired page 16 of 32 pages.
# Acquired page 17 of 32 pages.
# Acquired page 18 of 32 pages.
# Acquired page 19 of 32 pages.
# Acquired page 20 of 32 pages.
# Acquired page 21 of 32 pages.
# Acquired page 22 of 32 pages.
# Acquired page 23 of 32 pages.
# Acquired page 24 of 32 pages.
# Acquired page 25 of 32 pages.
# Acquired page 26 of 32 pages.
# Acquired page 27 of 32 pages.
# Acquired page 28 of 32 pages.
# Acquired page 29 of 32 pages.
# Acquired page 30 of 32 pages.
# Acquired page 31 of 32 pages.
# Acquired page 32 of 32 pages.
# Got first page of sub-genre: Sci-Fi and Fantasy, star-wars-fiction
# Acquired page 2 of 24 pages.
# Acquired page 3 of 24 pages.
# Acquired page 4 of 24 pages.
# Acquired page 5 of 24 pages.
# Acquired page 6 of 24 pages.
# Acquired page 7 of 24 pages.
# Acquired page 8 of 24 pages.
# Acquired page 9 of 24 pages.
# Acquired page 10 of 24 pages.
# Acquired page 11 of 24 pages.
# Acquired page 12 of 24 pages.
# Acquired page 13 of 24 pages.
# Acquired page 14 of 24 pages.
# Acquired page 15 of 24 pages.
# Acquired page 16 of 24 pages.
# Acquired page 17 of 24 pages.
# Acquired page 18 of 24 pages.
# Acquired page 19 of 24 pages.
# Acquired page 20 of 24 pages.
# Acquired page 21 of 24 pages.
# Acquired page 22 of 24 pages.
# Acquired page 23 of 24 pages.
# Acquired page 24 of 24 pages.

# %%
len(book_urls)
# Out:
# 29340

# %% [markdown]
# Awesome, now that I have the URLs for each individual book, I can begin scraping their cover blurbs. However, I will first convert 'book_urls' to a df, remove any duplicates, and save it as a .csv.

# %%
#Convert to data frame
url_df = pd.DataFrame(book_urls)

# %%
url_df.head()
# Out:
#     genre      sub-genre                                                url
# 0  Horror  ghost-stories  https://www.barnesandnoble.com/w/a-christmas-c...
# 1  Horror  ghost-stories  https://www.barnesandnoble.com/w/we-have-alway...
# 2  Horror  ghost-stories  https://www.barnesandnoble.com/w/haunting-of-h...
# 3  Horror  ghost-stories  https://www.barnesandnoble.com/w/nothing-but-b...
# 4  Horror  ghost-stories  https://www.barnesandnoble.com/w/horrorstor-gr...

# %%
url_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29340 entries, 0 to 29339
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   genre      29340 non-null  object
#  1   sub-genre  29340 non-null  object
#  2   url        29340 non-null  object
# dtypes: object(3)
# memory usage: 687.8+ KB

# %%
#Remove any duplicate urls
url_df = url_df.drop_duplicates(subset = ['url'])

# %%
url_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21640 entries, 0 to 29339
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   genre      21640 non-null  object
#  1   sub-genre  21640 non-null  object
#  2   url        21640 non-null  object
# dtypes: object(3)
# memory usage: 676.2+ KB

# %% [markdown]
# We started with 29,340 entries, but after removing duplicates, we are left with 21,640 entries.

# %% [markdown]
# How many are in each genre?

# %%
url_df.genre.value_counts(normalize = True)
# Out:
# Sci-Fi and Fantasy    0.317329
# Horror                0.303235
# Mystery and Crime     0.205499
# Romance               0.173937
# Name: genre, dtype: float64

# %% [markdown]
# I don't think these proportions are ridiculous.

# %%
#Now save url_df as a .csv
url_df.to_csv('book_urls.csv', index = False)

# %%
book_urls = url_df.to_dict()

# %%
#Now get the cover blurbs
response = get(book_urls[1]['url'], headers = {'user-agent': 'Codeup DS Germain'})

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
#Get the description
blurb = soup.find('div', itemprop = 'description')

# %%
blurb.text.strip().replace('\xa0 ', '')
# Out:
# 'Part of the Penguin Orange Collection, a limited-run series of twelve influential and beloved American classics in a bold series design offering a modern take on the iconic Penguin paperbackWinner of the 2016 AIGA + Design Observer 50 Books | 50 Covers competitionFor the seventieth anniversary of Penguin Classics, the Penguin Orange Collection celebrates the heritage of Penguin’s iconic book design with twelve influential American literary classics representing the breadth and diversity of the Penguin Classics library. These collectible editions are dressed in the iconic orange and white tri-band cover design, first created in 1935, while french flaps, high-quality paper, and striking cover illustrations provide the cutting-edge design treatment that is the signature of Penguin Classics Deluxe Editions today.We Have Always Lived in the Castle Taking readers deep into a labyrinth of dark neurosis, We Have Always Lived in the Castle is perhaps the crowning achievement of Shirley Jackson’s brilliant career: a deliciously unsettling novel about a perverse, isolated, and possibly murderous family and the dramatic struggle that ensues when an unexpected visitor interrupts their unusual way of life.'

# %%
#Now create a function that loops through all the urls and retrieves the description of each book
def get_book_blurbs(book_urls):
    """
    This function takes in a list of dictionaries that contain a book's overall genre, its sub-genre,
    and its unique url. This function will loop through each url in the given list of dictionaries,
    and scrape the description of each book. It will finally return a new list of dictionaries with 
    the books' descriptions included. It will also keep track of how long the function runs.
    """
    #Start the timer
    time_start = time.perf_counter()
    
    #Create a variable to keep track of the number of books that didn't have a blurb
    books_skipped = 0
    
    #Create a variable to keep track of the number of books that have been processed
    book_number = 0
    
    #Create the empty list to store the dictionaries
    book_blurbs = []
    
    #Now loop through each book url in the 'book_urls'
    for book in book_urls:
        #Update book_number
        book_number += 1
        
        #Every 100 entries, leave a progress message
        if book_number % 100 == 0:
            print(f'Total Entries So Far: {book_number}')
            print(f'Total Entries Left: {len(book_urls) - book_number}')
            print(f'Total Time So Far: { (time.perf_counter() - time_start) / 60} minutes\n')
        
        #Get the page content
        response = get(book['url'], headers = {'user-agent': 'Codeup DS Germain'})
        
        #Check the status code. If there is a problem, leave a message
        if response.status_code != 200:
            print(f'Something went wrong at book url #{book_number}! Status Code: {response.status_code}')
            print(f'Genre, Subgenre: {book["genre"]}, {book["sub-genre"]}')
            print(f'Book URL: {book["url"]}')
            continue
        
        #parse it
        soup = BeautifulSoup(response.content, 'html.parser')
        
        #Get the description
        blurb = soup.find('div', itemprop = 'description')
        
        #For testing
        #print(f"Current URL: {book['url']}")
        #print(f"Number: {book_number}")
        
        #Check that the description exists. If it does,
        #Remove leading and trailing whitespace and '\xa0'
        #Otherwise, continue the loop
        if blurb != None:
            blurb = blurb.text.strip().replace('\xa0 ', '')
        else:
            books_skipped += 1
            print(f"Book Skipped! URL: {book['url']}")
            print(f"Book Number: {book_number}\n")
            continue
        
        #Create temp dict
        temp_dict = {'genre': book['genre'],
                     'sub-genre': book['sub-genre'],
                     'blurb': blurb
                    }
        
        #Append the temp_dict to the book_blurbs list
        book_blurbs.append(temp_dict)
        
        #For testing
        #print(f'Book Number #{book_number} Complete.')
        
    #Inform the user that the function is done. Provide total time
    print(f'Function Complete! Total Time: { (time.perf_counter() - time_start) / 60 / 60} hours')
    print(f'Total Books Skipped: {books_skipped}')
    
    return book_blurbs

# %%
#Load the book_urls from the .csv file
book_urls = pd.read_csv('book_urls.csv')

#Now create separate dfs for each genre
horror_df = book_urls[book_urls.genre == 'Horror']
romance_df = book_urls[book_urls.genre == 'Romance']
mystery_df = book_urls[book_urls.genre == 'Mystery and Crime']
fantasy_df = book_urls[book_urls.genre == 'Sci-Fi and Fantasy']

#Convert to a dict for ease of use in the function
horror_urls = horror_df.to_dict('records')
romance_urls = romance_df.to_dict('records')
mystery_urls = mystery_df.to_dict('records')
fantasy_urls = fantasy_df.to_dict('records')

# %%
#Now use the function above to retrieve all the individual book blurbs
#Since doing them all at the same time is proving to be difficult,
#Set up a series of function calls to get the blurbs one overall genre at a time

#For the Horror Section:
horror_blurbs = get_book_blurbs(horror_urls)
# Out:
# Book Skipped! URL: https://www.barnesandnoble.com/w/naomis-room-jonathan-aycliffe/1128572938
# Book Number: 97
#
# Total Entries So Far: 100
# Total Entries Left: 6462
# Total Time So Far: 2.223635836816781 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/ghost-stories-of-henry-james-henry-james/1004847591
# Book Number: 136
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/ghostly-horrors-book-one-christopher-harman/1139576752
# Book Number: 162
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/l-etrange-odd-thomas-dean-koontz/1107045299
# Book Number: 181
#
# Total Entries So Far: 200
# Total Entries Left: 6362
# Total Time So Far: 4.433746498616771 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/a-christmas-carol-the-original-manuscript-charles-dickens/1104158164
# Book Number: 232
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/j-s-le-fanus-ghostly-tales-j-sheridan-le-fanu/1100159963
# Book Number: 252
#
# Total Entries So Far: 300
# Total Entries Left: 6262
# Total Time So Far: 6.433934605566659 minutes
#
# Total Entries So Far: 400
# Total Entries Left: 6162
# Total Time So Far: 8.287477266666732 minutes
#
# Total Entries So Far: 500
# Total Entries Left: 6062
# Total Time So Far: 10.144461123616686 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/la-llorona-judith-s-beatty/1112404474
# Book Number: 535
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/a-spirited-tail-leighann-dobbs/1120036220
# Book Number: 569
#
# Total Entries So Far: 600
# Total Entries Left: 5962
# Total Time So Far: 12.008213451399934 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/dark-music-e-f-watkins/1115091641
# Book Number: 633
#
# Total Entries So Far: 700
# Total Entries Left: 5862
# Total Time So Far: 14.131293641666707 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/the-cemetery-gang-barbara-j-rohlehr/1113907694
# Book Number: 713
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/the-legend-of-the-girl-from-the-shadows-mcr-el-pensador/1112843390
# Book Number: 764
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/the-ghosts-of-moonlight-creek-sue-copsey/1128134570
# Book Number: 776
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/lilly-alynia-h-rule/1113803191
# Book Number: 797
#
# Total Entries So Far: 800
# Total Entries Left: 5762
# Total Time So Far: 16.431923275699955 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/ali-thomas-warner/1108801776
# Book Number: 809
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/tome-of-horror-david-maurice-garrett/1024289588
# Book Number: 810
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/molly-greysons-ghost-roberta-hoffer/1125018056
# Book Number: 878
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/the-epic-saga-of-jonahs-curse-joshua-t-douglas/1121112815
# Book Number: 883
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/spirits-of-seacliff-manor-morgan-hannah-macdonald/1125413988
# Book Number: 888
#
# Total Entries So Far: 900
# Total Entries Left: 5662
# Total Time So Far: 18.654127462500036 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/the-chariot-of-death-mcr-el-pensador/1112947614
# Book Number: 934
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/saving-lost-souls-manon-riendeau/1109802599
# Book Number: 963
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/the-witches-cavern-allison-bruning/1124741216
# Book Number: 994
#
# Total Entries So Far: 1000
# Total Entries Left: 5562
# Total Time So Far: 20.79084889166673 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w
minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/a-concise-treatise-on-lycanthropy-andreas-shibilis/1130860952
# Book Number: 6129
#
# Total Entries So Far: 6200
# Total Entries Left: 362
# Total Time So Far: 131.78481316528342 minutes
#
# Total Entries So Far: 6300
# Total Entries Left: 262
# Total Time So Far: 133.8612805486167 minutes
#
# Total Entries So Far: 6400
# Total Entries Left: 162
# Total Time So Far: 135.9950770132001 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/zombie-apocalypse-end-game-stephen-jones/1118741428
# Book Number: 6451
#
# Total Entries So Far: 6500
# Total Entries Left: 62
# Total Time So Far: 138.35375711320012 minutes
#
# Function Complete! Total Time: 2.3301237368866676 hours
# Total Books Skipped: 126

# %%
#For the romance section
romance_blurbs = get_book_blurbs(romance_urls)
# Out:
# Book Skipped! URL: https://www.barnesandnoble.com/w/reckless-whisper-barbara-freethy/1128003500
# Book Number: 51
#
# Total Entries So Far: 100
# Total Entries Left: 3664
# Total Time So Far: 2.14018712499989 minutes
#
# Total Entries So Far: 200
# Total Entries Left: 3564
# Total Time So Far: 4.154010588899837 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/perilous-trust-barbara-freethy/1126577323
# Book Number: 247
#
# Total Entries So Far: 300
# Total Entries Left: 3464
# Total Time So Far: 6.526487890283169 minutes
#
# Total Entries So Far: 400
# Total Entries Left: 3364
# Total Time So Far: 8.816849808333306 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/strong-and-steady-vanessa-vale/1138536139
# Book Number: 404
#
# Total Entries So Far: 500
# Total Entries Left: 3264
# Total Time So Far: 11.117499501400015 minutes
#
# Total Entries So Far: 600
# Total Entries Left: 3164
# Total Time So Far: 13.414638159733295 minutes
#
# Total Entries So Far: 700
# Total Entries Left: 3064
# Total Time So Far: 15.374031121533335 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/rhapsodic-laura-thalassa/1125351634
# Book Number: 794
#
# Total Entries So Far: 800
# Total Entries Left: 2964
# Total Time So Far: 17.408372076399974 minutes
#
# Total Entries So Far: 900
# Total Entries Left: 2864
# Total Time So Far: 19.28968055486645 minutes
#
# Total Entries So Far: 1000
# Total Entries Left: 2764
# Total Time So Far: 21.289535214583157 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/love-is-all-around-holiday-collection-darcy-burke/1140440077
# Book Number: 1026
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/the-games-lovers-play-stephanie-laurens/1138597393
# Book Number: 1072
#
# Total Entries So Far: 1100
# Total Entries Left: 2664
# Total Time So Far: 23.638018098616644 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/scarlet-lies-jo-goodman/1129987342
# Book Number: 1195
#
# Total Entries So Far: 1200
# Total Entries Left: 2564
# Total Time So Far: 26.109447715283263 minutes
#
# Total Entries So Far: 1300
# Total Entries Left: 2464
# Total Time So Far: 28.744500224999985 minutes
#
# Total Entries So Far: 1400
# Total Entries Left: 2364
# Total Time So Far: 30.74142262431657 minutes
#
# Total Entries So Far: 1500
# Total Entries Left: 2264
# Total Time So Far: 32.81707123056646 minutes
#
# Total Entries So Far: 1600
# Total Entries Left: 2164
# Total Time So Far: 35.23679286806655 minutes
#
# Total Entries So Far: 1700
# Total Entries Left: 2064
# Total Time So Far: 37.39466165486665 minutes
#
# Total Entries So Far: 1800
# Total Entries Left: 1964
# Total Time So Far: 39.606530327083114 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/lady-beresfords-lover-ella-quinn/1121697420
# Book Number: 1815
#
# Total Entries So Far: 1900
# Total Entries Left: 1864
# Total Time So Far: 42.00553415208318 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/a-kiss-for-lady-mary-ella-quinn/1120611636
# Book Number: 1940
#
# Total Entries So Far: 2000
# Total Entries Left: 1764
# Total Time So Far: 44.15286336249992 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/the-light-years-elizabeth-jane-howard/1001920963
# Book Number: 2095
#
# Total Entries So Far: 2100
# Total Entries Left: 1664
# Total Time So Far: 46.62818435208319 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/midnight-days-anna-zaires/1139420678
# Book Number: 2105
#
# Total Entries So Far: 2200
# Total Entries Left: 1564
# Total Time So Far: 49.07244331528321 minutes
#
# Total Entries So Far: 2300
# Total Entries Left: 1464
# Total Time So Far: 51.39130204166649 minutes
#
# Total Entries So Far: 2400
# Total Entries Left: 1364
# Total Time So Far: 53.54990614098327 minutes
#
# Total Entries So Far: 2500
# Total Entries Left: 1264
# Total Time So Far: 55.816964211816476 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/diplomatic-immunity-lois-mcmaster-bujold/1103276289
# Book Number: 2545
#
# Total Entries So Far: 2600
# Total Entries Left: 1164
# Total Time So Far: 57.98104660139992 minutes
#
# Total Entries So Far: 2700
# Total Entries Left: 1064
# Total Time So Far: 60.12586315416653 minutes
#
# Total Entries So Far: 2800
# Total Entries Left: 964
# Total Time So Far: 62.18295362431648 minutes
#
# Total Entries So Far: 2900
# Total Entries Left: 864
# Total Time So Far: 64.21364215903328 minutes
#
# Total Entries So Far: 3000
# Total Entries Left: 764
# Total Time So Far: 66.2956912152833 minutes
#
# Total Entries So Far: 3100
# Total Entries Left: 664
# Total Time So Far: 68.73990777569998 minutes
#
# Total Entries So Far: 3200
# Total Entries Left: 564
# Total Time So Far: 71.2492511722332 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/wicked-ride-rebecca-zanetti/1120611632
# Book Number: 3227
#
# Total Entries So Far: 3300
# Total Entries Left: 464
# Total Time So Far: 73.5868978006998 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/tempted-twisted-tamed-rebecca-zanetti/1121860448
# Book Number: 3358
#
# Total Entries So Far: 3400
# Total Entries Left: 364
# Total Time So Far: 75.47123071319996 minutes
#
# Total Entries So Far: 3500
# Total Entries Left: 264
# Total Time So Far: 77.47820354028323 minutes
#
# Total Entries So Far: 3600
# Total Entries Left: 164
# Total Time So Far: 79.32140869791668 minutes
#
# Total Entries So Far: 3700
# Total Entries Left: 64
# Total Time So Far: 81.80643573681664 minutes
#
# Function Complete! Total Time: 1.3879634152777767 hours
# Total Books Skipped: 14

# %%
#For the mystery and crime section
mystery_blurbs = get_book_blurbs(mystery_urls)
# Out:
# Total Entries So Far: 100
# Total Entries Left: 4347
# Total Time So Far: 1.882589200000075 minutes
#
# Total Entries So Far: 200
# Total Entries Left: 4247
# Total Time So Far: 3.891071822916759 minutes
#
# Total Entries So Far: 300
# Total Entries Left: 4147
# Total Time So Far: 5.9789307895834405 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/elusive-mrs-pollifax-dorothy-gilman/1101890316
# Book Number: 370
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/murder-on-wheels-stuart-palmer/1000259968
# Book Number: 383
#
# Total Entries So Far: 400
# Total Entries Left: 4047
# Total Time So Far: 8.209251349300029 minutes
#
# Total Entries So Far: 500
# Total Entries Left: 3947
# Total Time So Far: 10.608664697216833 minutes
#
# Total Entries So Far: 600
# Total Entries Left: 3847
# Total Time So Far: 13.059611201383328 minutes
#
# Total Entries So Far: 700
# Total Entries Left: 3747
# Total Time So Far: 15.073481829166848 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/amazing-mrs-pollifax-dorothy-gilman/1102301996
# Book Number: 732
#
# Total Entries So Far: 800
# Total Entries Left: 3647
# Total Time So Far: 17.27517917360019 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/mrs-pollifax-pursued-dorothy-gilman/1101956208
# Book Number: 887
#
# Total Entries So Far: 900
# Total Entries Left: 3547
# Total Time So Far: 19.302737515266685 minutes
#
# Total Entries So Far: 1000
# Total Entries Left: 3447
# Total Time So Far: 21.686019323600096 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/left-to-lapse-blake-pierce/1137060345
# Book Number: 1014
#
# Total Entries So Far: 1100
# Total Entries Left: 3347
# Total Time So Far: 24.00300754513349 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/left-to-envy-blake-pierce/1137060324
# Book Number: 1159
#
# Total Entries So Far: 1200
# Total Entries Left: 3247
# Total Time So Far: 26.037825136800045 minutes
#
# Total Entries So Far: 1300
# Total Entries Left: 3147
# Total Time So Far: 28.62877309375011 minutes
#
# Total Entries So Far: 1400
# Total Entries Left: 3047
# Total Time So Far: 31.834260220133487 minutes
#
# Total Entries So Far: 1500
# Total Entries Left: 2947
# Total Time So Far: 34.98422760000006 minutes
#
# Total Entries So Far: 1600
# Total Entries Left: 2847
# Total Time So Far: 37.811495106933336 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/the-dispatcher-john-scalzi/1138337829
# Book Number: 1680
#
# Total Entries So Far: 1700
# Total Entries Left: 2747
# Total Time So Far: 40.9080383111 minutes
#
# Total Entries So Far: 1800
# Total Entries Left: 2647
# Total Time So Far: 43.97173789443332 minutes
#
# Total Entries So Far: 1900
# Total Entries Left: 2547
# Total Time So Far: 46.30468069513348 minutes
#
# Total Entries So Far: 2000
# Total Entries Left: 2447
# Total Time So Far: 48.51134407846669 minutes
#
# Total Entries So Far: 2100
# Total Entries Left: 2347
# Total Time So Far: 51.651075093750116 minutes
#
# Total Entries So Far: 2200
# Total Entries Left: 2247
# Total Time So Far: 54.88834503958351 minutes
#
# Total Entries So Far: 2300
# Total Entries Left: 2147
# Total Time So Far: 57.99736829583344 minutes
#
# Total Entries So Far: 2400
# Total Entries Left: 2047
# Total Time So Far: 61.05305866318352 minutes
#
# Total Entries So Far: 2500
# Total Entries Left: 1947
# Total Time So Far: 63.77023784721678 minutes
#
# Total Entries So Far: 2600
# Total Entries Left: 1847
# Total Time So Far: 66.2649029875002 minutes
#
# Total Entries So Far: 2700
# Total Entries Left: 1747
# Total Time So Far: 68.47307485000007 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/the-effects-of-her-nerium-francheska-robles/1139994690
# Book Number: 2783
#
# Total Entries So Far: 2800
# Total Entries Left: 1647
# Total Time So Far: 71.09965656109998 minutes
#
# Total Entries So Far: 2900
# Total Entries Left: 1547
# Total Time So Far: 73.56843318610021 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/coffin-man-james-d-doss/1102250436
# Book Number: 2906
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/stone-butterfly-james-d-doss/1103099513
# Book Number: 2942
#
# Total Entries So Far: 3000
# Total Entries Left: 1447
# Total Time So Far: 75.97605760138346 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/the-owl-and-the-raven-micah-s-hackler/1131255035
# Book Number: 3096
#
# Total Entries So Far: 3100
# Total Entries Left: 1347
# Total Time So Far: 78.30467794026676 minutes
#
# Total Entries So Far: 3200
# Total Entries Left: 1247
# Total Time So Far: 80.6809414770835 minutes
#
# Total Entries So Far: 3300
# Total Entries Left: 1147
# Total Time So Far: 83.00136045763333 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/new-radeaux-e-l-watkins/1139190282
# Book Number: 3329
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/shadow-man-james-d-doss/1100340752
# Book Number: 3354
#
# Total Entries So Far: 3400
# Total Entries Left: 1047
# Total Time So Far: 85.23444771458331 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/criss-cross-evie-rhodes/1101241874
# Book Number: 3415
#
# Total Entries So Far: 3500
# Total Entries Left: 947
# Total Time So Far: 87.25607947776686 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/henrietta-who-catherine-aird/1113836454
# Book Number: 3500
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/test-of-wills-charles-todd/1100615990
# Book Number: 3540
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/good-for-justice-joseph-novak-jr/1140432313
# Book Number: 3542
#
# Total Entries So Far: 3600
# Total Entries Left: 847
# Total Time So Far: 89.28859446875019 minutes
#
# Total Entries So Far: 3700
# Total Entries Left: 747
# Total Time So Far: 91.58231354930007 minutes
#
# Total Entries So Far: 3800
# Total Entries Left: 647
# Total Time So Far: 94.20728095763334 minutes
#
# Total Entries So Far: 3900
# Total Entries Left: 547
# Total Time So Far: 96.78178784375001 minutes
#
# Total Entries So Far: 4000
# Total Entries Left: 447
# Total Time So Far: 99.04024518125007 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/mackenzie-white-mystery-bundle-blake-pierce/1137139724
# Book Number: 4022
#
# Total Entries So Far: 4100
# Total Entries Left: 347
# Total Time So Far: 101.36417529166671 minutes
#
# Total Entries So Far: 4200
# Total Entries Left: 247
# Total Time So Far: 103.50553567221674 minutes
#
# Total Entries So Far: 4300
# Total Entries Left: 147
# Total Time So Far: 105.57463380416667 minutes
#
# Total Entries So Far: 4400
# Total Entries Left: 47
# Total Time So Far: 107.74845102151667 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/his-burial-too-catherine-aird/1000753039
# Book Number: 4401
#
# Function Complete! Total Time: 1.8145237586688907 hours
# Total Books Skipped: 19

# %%
#For the Sci-Fi and Fantasy section
fantasy_blurbs = get_book_blurbs(fantasy_urls)
# Out:
# Total Entries So Far: 100
# Total Entries Left: 6767
# Total Time So Far: 2.462460545149952 minutes
#
# Total Entries So Far: 200
# Total Entries Left: 6667
# Total Time So Far: 4.878980602083175 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/1633-david-weber/1103276295
# Book Number: 232
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/the-foundation-trilogy-isaac-asimov/1136897244
# Book Number: 240
#
# Total Entries So Far: 300
# Total Entries Left: 6567
# Total Time So Far: 7.169347404166668 minutes
#
# Total Entries So Far: 400
# Total Entries Left: 6467
# Total Time So Far: 9.606513279866583 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/echoes-of-honor-david-weber/1103139742
# Book Number: 493
#
# Total Entries So Far: 500
# Total Entries Left: 6367
# Total Time So Far: 11.736859473616642 minutes
#
# Total Entries So Far: 600
# Total Entries Left: 6267
# Total Time So Far: 14.08208560973338 minutes
#
# Total Entries So Far: 700
# Total Entries Left: 6167
# Total Time So Far: 16.375309710416573 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/taldra-duane-simolke/1138452828
# Book Number: 780
#
# Total Entries So Far: 800
# Total Entries Left: 6067
# Total Time So Far: 18.187926696533395 minutes
#
# Total Entries So Far: 900
# Total Entries Left: 5967
# Total Time So Far: 20.503150900000037 minutes
#
# Total Entries So Far: 1000
# Total Entries Left: 5867
# Total Time So Far: 23.055899442366595 minutes
#
# Total Entries So Far: 1100
# Total Entries Left: 5767
# Total Time So Far: 25.523243333333326 minutes
#
# Total Entries So Far: 1200
# Total Entries Left: 5667
# Total Time So Far: 27.85183436458319 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/night-of-the-bold-morgan-rice/1122919166
# Book Number: 1284
#
# Total Entries So Far: 1300
# Total Entries Left: 5567
# Total Time So Far: 30.38411002986662 minutes
#
# Total Entries So Far: 1400
# Total Entries Left: 5467
# Total Time So Far: 32.68301167014991 minutes
#
# Total Entries So Far: 1500
# Total Entries Left: 5367
# Total Time So Far: 34.835267933333185 minutes
#
# Total Entries So Far: 1600
# Total Entries Left: 5267
# Total Time So Far: 37.202095462499955 minutes
#
# Total Entries So Far: 1700
# Total Entries Left: 5167
# Total Time So Far: 39.29666736666671 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/komarr-lois-mcmaster-bujold/1102823228
# Book Number: 1774
#
# Total Entries So Far: 1800
# Total Entries Left: 5067
# Total Time So Far: 41.380922660416644 minutes
#
# Total Entries So Far: 1900
# Total Entries Left: 4967
# Total Time So Far: 43.604412387499906 minutes
#
# Total Entries So Far: 2000
# Total Entries Left: 4867
# Total Time So Far: 46.09505984861656 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/pensad-en-flebas-iain-m-banks/1110625142
# Book Number: 2029
#
# Total Entries So Far: 2100
# Total Entries Left: 4767
# Total Time So Far: 48.48563205348328 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/the-excalibur-alternative-david-weber/1004877499
# Book Number: 2126
#
# Total Entries So Far: 2200
# Total Entries Left: 4667
# Total Time So Far: 50.91256428403334 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/worlds-of-honor-david-weber/1102823229
# Book Number: 2247
#
# Total Entries So Far: 2300
# Total Entries Left: 4567
# Total Time So Far: 53.47314706041652 minutes
#
# Total Entries So Far: 2400
# Total Entries Left: 4467
# Total Time So Far: 55.97468875069996 minutes
#
# Total Entries So Far: 2500
# Total Entries Left: 4367
# Total Time So Far: 58.14554136874988 minutes
#
# Total Entries So Far: 2600
# Total Entries Left: 4267
# Total Time So Far: 60.31231634098319 minutes
#
# Total Entries So Far: 2700
# Total Entries Left: 4167
# Total Time So Far: 62.36874150764997 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/monstress-volume-3-marjorie-liu/1130583685
# Book Number: 2708
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/and-eternity-piers-anthony/1102914488
# Book Number: 2735
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/war-gods-own-david-weber/1102002580
# Book Number: 2784
#
# Total Entries So Far: 2800
# Total Entries Left: 4067
# Total Time So Far: 64.2592164222333 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/martian-tales-trilogy-edgar-rice-burroughs/1100059637
# Book Number: 2804
#
# Total Entries So Far: 2900
# Total Entries Left: 3967
# Total Time So Far: 66.30712230833329 minutes
#
# Total Entries So Far: 3000
# Total Entries Left: 3867
# Total Time So Far: 68.27000670416673 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/rise-of-the-dragons-morgan-rice/1120956618
# Book Number: 3025
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/spirits-white-as-lightning-mercedes-lackey/1017979708
# Book Number: 3087
#
# Total Entries So Far: 3100
# Total Entries Left: 3767
# Total Time So Far: 70.51543074791674 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/the
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/star-wars-k-w-jeter/1140363643
# Book Number: 6556
#
# Total Entries So Far: 6600
# Total Entries Left: 267
# Total Time So Far: 148.00990731458322 minutes
#
# Total Entries So Far: 6700
# Total Entries Left: 167
# Total Time So Far: 150.23698366389993 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/star-wars-marvel-comics/1139955928
# Book Number: 6746
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/star-wars-marjorie-liu/1126378595
# Book Number: 6792
#
# Total Entries So Far: 6800
# Total Entries Left: 67
# Total Time So Far: 152.4250131805665 minutes
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/star-wars-marjorie-liu/1126378598
# Book Number: 6805
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/star-wars-marjorie-liu/1126378599
# Book Number: 6806
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/star-wars-epic-battles-simon-beecroft/1009027619
# Book Number: 6807
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/star-wars-marjorie-liu/1126378597
# Book Number: 6823
#
# Book Skipped! URL: https://www.barnesandnoble.com/w/star-wars-marjorie-liu/1126378596
# Book Number: 6863
#
# Function Complete! Total Time: 2.56379938391222 hours
# Total Books Skipped: 65

# %%
fantasy_blurbs[0]
# Out:
# {'genre': 'Sci-Fi and Fantasy',
#  'sub-genre': 'alternate-realities-fiction',
#  'blurb': 'The inspiration for the Syfy miniseries. Childhood’s End is one of the defining legacies of Arthur C. Clarke, the author of 2001: A Space Odyssey and many other groundbreaking works. Since its publication in 1953, this prescient novel about first contact gone wrong has come to be regarded not only as a science fiction classic but as a literary thriller of the highest order. Spaceships have suddenly appeared in the skies above every city on the planet. Inside is an intellectually, technologically, and militarily superior alien race known as the Overlords. At first, their demands seem benevolent: unify Earth, eliminate poverty, end war. But at what cost? To those who resist, it’s clear that the Overlords have an agenda of their own. Has their arrival marked the end of humankind . . . or the beginning? Praise for Childhood’s End “A first-rate tour de force.”—The New York Times “Frighteningly logical, believable, and grimly prophetic . . . Clarke is a master.”—Los Angeles Times “There has been nothing like it for years; partly for the actual invention, but partly because here we meet a modern author who understands that there may be things that have a higher claim on humanity than its own ‘survival.’ ”—C. S. Lewis “As a science fiction writer, Clarke has all the essentials.”—Jeremy Bernstein, The New Yorker'}

# %%
#Now that all the data has been acquired, create a new list to hold all entries
book_blurbs = []

# %%
#Now extend book_blurbs with all the data
book_blurbs.extend(horror_blurbs)
book_blurbs.extend(romance_blurbs)
book_blurbs.extend(mystery_blurbs)
book_blurbs.extend(fantasy_blurbs)

# %%
len(book_blurbs)
# Out:
# 21416

# %%
#Now that the data is all in one list, convert it to a df and save a csv file
book_blurbs = pd.DataFrame(book_blurbs)

# %%
book_blurbs.head()
# Out:
#     genre      sub-genre                                              blurb
# 0  Horror  ghost-stories  Designed to appeal to the book lover, the Macm...
# 1  Horror  ghost-stories  Part of the Penguin Orange Collection, a limit...
# 2  Horror  ghost-stories  Part of a new six-volume series of the best in...
# 3  Horror  ghost-stories  A USA TODAY BESTSELLER!An Indie Next Pick!An O...
# 4  Horror  ghost-stories  From the New York Times best-selling author of...

# %%
#Convert horror blurbs to df and save as csv
horror_blurbs = pd.DataFrame(horror_blurbs)
horror_blurbs.to_csv('horror_blurbs.csv', index = False)

# %%
#Convert Romance blurbs to df and save as csv
romance_blurbs = pd.DataFrame(romance_blurbs)
romance_blurbs.to_csv('romance_blurbs.csv', index = False)

aining book filled with a wonderful Christian witness. I am looking forward to reading the next book in the series.★★★★★ A well written book full of both faith and humor. You will enjoy this. I will be reading more of her books.★★★★★ I enjoyed this book because it was a mystery without a lot of clutter. Jane is a quirky, everyday person struggling with things we all do. An enjoyable easy read.★★★★★ The title says it all. What a fun book. Great characters! I love that there are Christian authors putting out mysteries now! \ud83d\ude01★★★★★ Good, Clean, Murder is delightful reading, a murder mystery without anyone else getting hurt.★★★★★ What a surprise from the typical cozy mysteries. And the murder victims.... wow! Loved the story and the "clean" approach. Good Christian r ...

# %%
mystery_blurbs = mystery_blurbs.drop(mystery_blurbs.index[558])

# %%
#After dropping what I think was the problem, try saving it as a csv again
mystery_blurbs.to_csv('mystery_blurbs.csv', index = False)

# %%
#Convert fantasy_blurbs to df and save as csv
fantasy_blurbs = pd.DataFrame(fantasy_blurbs)
fantasy_blurbs.to_csv('fantasy_blurbs.csv', index = False)

# %% [markdown]
# # Clean the Data

# %%
import prepare

# %%
#Prepare the df
book_blurbs = prepare.prepare_articles(book_blurbs, 'blurb')

# %%
book_blurbs.head()
# Out:
#     genre      sub-genre                                           original  \
# 0  Horror  ghost-stories  Designed to appeal to the book lover, the Macm...
# 1  Horror  ghost-stories  Part of the Penguin Orange Collection, a limit...
# 2  Horror  ghost-stories  Part of a new six-volume series of the best in...
# 3  Horror  ghost-stories  A USA TODAY BESTSELLER!An Indie Next Pick!An O...
# 4  Horror  ghost-stories  From the New York Times best-selling author of...
#
#                                                clean  \
# 0  designed appeal book lover macmillan collector...
# 1  part penguin orange collection limitedrun seri...
# 2  part new sixvolume series best classic horror ...
# 3  usa today bestselleran indie next pickan octob...
# 4  new york times bestselling author southern boo...
#
#                                              stemmed  \
# 0  design appeal book lover macmillan collector '...
# 1  part penguin orang collect limitedrun seri twe...
# 2  part new sixvolum seri best classic horror sel...
# 3  usa today bestselleran indi next pickan octob ...
# 4  new york time bestsel author southern book clu...
#
#                                           lemmatized
# 0  designed appeal book lover macmillan collector...
# 1  part penguin orange collection limitedrun seri...
# 2  part new sixvolume series best classic horror ...
# 3  usa today bestselleran indie next pickan octob...
# 4  new york time bestselling author southern book...

# %%
#Looks like the same problem as before. Since I combined the blurbs before removing the bad one,
#I have to remove it again here.
#Find it
len(horror_blurbs) + len(romance_blurbs) + 558
# Out:
# 10744

# %%
book_blurbs[10744:10745]
# Out:
#                    genre                       sub-genre  \
# 10744  Mystery and Crime  cozy-mysteries-amateur-sleuths
#
#                                                 original  \
# 10744  The road to her dreams is cluttered with corps...
#
#                                                    clean  \
# 10744  road dreams cluttered corpses jane clean deadl...
#
#                                                  stemmed  \
# 10744  road dream clutter corps jane clean deadli mes...
#
#                                               lemmatized
# 10744  road dream cluttered corps jane clean deadly m...

# %%
#That's the one. Drop it
book_blurbs = book_blurbs.drop(book_blurbs.index[10744])

# %%
#Save as .csv
book_blurbs.to_csv('cleaned_book_blurbs.csv', index = False)

# %% [markdown]
# Complete! I now have all the data I need in .csv format. I no longer need to webscrape to get it.
